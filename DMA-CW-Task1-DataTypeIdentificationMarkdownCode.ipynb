# %% [markdown]
# #### Task 1 - Data Type Identification
# | **Variable Name** | **Qualitative/Quantitative** | **Discrete/Continuous** |
# | --- | --- | --- |
# | traffic_flow | Qualitative | Discrete |
# | pm25 | Qualitative | Continuous |
# | noise | Qualitative | Discrete |
# | temperature | Qualitative | Continuous |
# | day_type | Quantitative | Discrete |
# | region | Quantitative | Discrete |

# %% [markdown]
# #### Task 2 - Data Type Identification
# | **Variable Name** | **Mean** | **Median** | **Mode** |
# | --- | --- | --- | --- |
# | traffic_flow | 748.02 (2dp) | 770 | 1080 |
# | pm25 | 34.62 (2dp) | 35.24 (2dp) | 5.0 |
